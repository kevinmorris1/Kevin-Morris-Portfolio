# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
standings_url = "https://www.baseball-reference.com/"

data = requests.get(standings_url)
soup = BeautifulSoup(data.text, features='lxml')
tables = soup.select('table#standings_AL') + soup.select('table#standings_NL')

urls = []
for t in tables:
    links = t.find_all('a')
    links = [l.get("href") for l in links] 
    links = [f"https://www.baseball-reference.com{l}" for l in links] 
    urls = urls + links

# %%
df = pd.DataFrame()
for i in range(len(urls)):
    url = urls[i] # first club page link
    print(url)
    data = requests.get(url) 

    soup = BeautifulSoup(data.text, features='lxml') # extract all information from page
    links = soup.find_all('a') # find all links on page for the club
    links = [l.get("href") for l in links] # get reference urls for those links
    links = [l for l in links if l and (('schedule-scores' in l))]
    links = [*set(links)][0]

    sch_url = f"https://www.baseball-reference.com{links}"
    data = requests.get(sch_url) 
    sch = pd.read_html(data.text, match='Team Game-by-Game Schedule')[0]

    df = df.append(sch)
    time.sleep(1)
# Out:
# https://www.baseball-reference.com/teams/NYY/2022.shtml
# https://www.baseball-reference.com/teams/TBR/2022.shtml
# https://www.baseball-reference.com/teams/TOR/2022.shtml
# https://www.baseball-reference.com/teams/BAL/2022.shtml
# https://www.baseball-reference.com/teams/BOS/2022.shtml
# https://www.baseball-reference.com/teams/CLE/2022.shtml
# https://www.baseball-reference.com/teams/MIN/2022.shtml
# https://www.baseball-reference.com/teams/CHW/2022.shtml
# https://www.baseball-reference.com/teams/KCR/2022.shtml
# https://www.baseball-reference.com/teams/DET/2022.shtml
# https://www.baseball-reference.com/teams/HOU/2022.shtml
# https://www.baseball-reference.com/teams/SEA/2022.shtml
# https://www.baseball-reference.com/teams/TEX/2022.shtml
# https://www.baseball-reference.com/teams/LAA/2022.shtml
# https://www.baseball-reference.com/teams/OAK/2022.shtml
# https://www.baseball-reference.com/teams/NYM/2022.shtml
# https://www.baseball-reference.com/teams/ATL/2022.shtml
# https://www.baseball-reference.com/teams/PHI/2022.shtml
# https://www.baseball-reference.com/teams/MIA/2022.shtml
# https://www.baseball-reference.com/teams/WSN/2022.shtml
# https://www.baseball-reference.com/teams/STL/2022.shtml
# https://www.baseball-reference.com/teams/MIL/2022.shtml
# https://www.baseball-reference.com/teams/CHC/2022.shtml
# https://www.baseball-reference.com/teams/CIN/2022.shtml
# https://www.baseball-reference.com/teams/PIT/2022.shtml
# https://www.baseball-reference.com/teams/LAD/2022.shtml
# https://www.baseball-reference.com/teams/SDP/2022.shtml
# https://www.baseball-reference.com/teams/SFG/2022.shtml
# https://www.baseball-reference.com/teams/ARI/2022.shtml
# https://www.baseball-reference.com/teams/COL/2022.shtml

# %%
df
# Out:
#      Gm#              Date Unnamed: 2   Tm Unnamed: 4  Opp       W/L  \
# 0      1     Friday, Apr 8   boxscore  NYY        NaN  BOS      W-wo
# 1      2   Saturday, Apr 9   boxscore  NYY        NaN  BOS         W
# 2      3    Sunday, Apr 10   boxscore  NYY        NaN  BOS         L
# 3      4    Monday, Apr 11   boxscore  NYY        NaN  TOR         L
# 4      5   Tuesday, Apr 12   boxscore  NYY        NaN  TOR         W
# ..   ...               ...        ...  ...        ...  ...       ...
# 164  159     Sunday, Oct 2    preview  COL          @  LAD   4:10 pm
# 165  160     Monday, Oct 3    preview  COL          @  LAD  10:10 pm
# 166  161    Tuesday, Oct 4    preview  COL          @  LAD  10:10 pm
# 167  162  Wednesday, Oct 5    preview  COL          @  LAD   4:20 pm
# 168  Gm#              Date        NaN   Tm        NaN  Opp       NaN
#
#             R        RA                         Inn  ...  \
# 0           6         5                          11  ...
# 1           4         2                         NaN  ...
# 2           3         4                         NaN  ...
# 3           0         3                         NaN  ...
# 4           4         0                         NaN  ...
# ..        ...       ...                         ...  ...
# 164   4:10 pm   4:10 pm  Game Preview, and Matchups  ...
# 165  10:10 pm  10:10 pm  Game Preview, and Matchups  ...
# 166  10:10 pm  10:10 pm  Game Preview, and Matchups  ...
# 167   4:20 pm   4:20 pm  Game Preview, and Matchups  ...
# 168       NaN       NaN                         NaN  ...
#
#                              GB                         Win  \
# 0                          Tied                        King
# 1                          Tied                      Luetge
# 2                           1.0                    Crawford
# 3                           1.0                      Manoah
# 4                           1.0                      Holmes
# ..                          ...                         ...
# 164  Game Preview, and Matchups  Game Preview, and Matchups
# 165  Game Preview, and Matchups  Game Preview, and Matchups
# 166  Game Preview, and Matchups  Game Preview, and Matchups
# 167  Game Preview, and Matchups  Game Preview, and Matchups
# 168                         NaN                         NaN
#
#                            Loss                        Save  \
# 0                      Crawford                         NaN
# 1                       Pivetta                     Chapman
# 2                       Schmidt                     Diekman
# 3                       Taillon                      Romano
# 4                       Kikuchi                         NaN
# ..                          ...                         ...
# 164  Game Preview, and Matchups  Game Preview, and Matchups
# 165  Game Preview, and Matchups  Game Preview, and Matchups
# 166  Game Preview, and Matchups  Game Preview, and Matchups
# 167  Game Preview, and Matchups  Game Preview, and Matchups
# 168                         NaN                         NaN
#
#                            Time                         D/N  \
# 0                          3:56                           D
# 1                          2:58                           D
# 2                          3:40                           N
# 3                          3:03                           N
# 4                          3:07                           N
# ..                          ...                         ...
# 164  Game Preview, and Matchups  Game Preview, and Matchups
# 165  Game Preview, and Matchups  Game Preview, and Matchups
# 166  Game Preview, and Matchups  Game Preview, and Matchups
# 167  Game Preview, and Matchups  Game Preview, and Matchups
# 168                         NaN                         NaN
#
#                      Attendance   cLI Streak  Orig. Scheduled
# 0                         46097   .97      +              NaN
# 1                         46882  1.03     ++              NaN
# 2                         40108  1.04      -              NaN
# 3                         26211  1.05     --              NaN
# 4                         25068  1.03      +              NaN
# ..                          ...   ...    ...              ...
# 164  Game Preview, and Matchups   NaN    NaN              NaN
# 165  Game Preview, and Matchups   NaN    NaN              NaN
# 166  Game Preview, and Matchups   NaN    NaN              NaN
# 167  Game Preview, and Matchups   NaN    NaN              NaN
# 168                         NaN   D/N    cLI  Orig. Scheduled
#
# [5070 rows x 22 columns]
