# %% [markdown]
# # Logistic Regression for Classification
#
# ## Classification basics
#
# In many data science practices, we are interested in different *classification* question in the form of "which one":
#
# * Does this email belong in the spam folder or the inbox?
# * Is this customer more likely *to sign up* or *not to sign up* for a subscription service?
# * Does this image depict a donkey, a dog, a cat, or a rooster?
# * Which movie is a Netflix user most likely to watch next?
#
# As shown in following figure, in *classification* we aim to find a function or model which is able to assign an object into of the the $k$ predefined class labels based on the features $\mathrm x=[x_1, x_2, ..., x_d]$.
#
# ![Classfication.](https://raw.githubusercontent.com/binbenliu/Teaching/main/DataMining/classification.png)
#
#
# In machine learning, *classification* refers to describe two subtly different problems:
# * (i) those where we are interested only in hard assignments of examples to categories (classes), for example decision trees; and
# * (ii) those where we wish to make soft assignments, i.e., to assess the probability that each category applies, for example, logistic regression.
#
# The distinction tends to get blurred, in part, because often, even when we only care about hard assignments, we still use models that make soft assignments.
#
# ## 1. Logistic regression model
#
# In statistics, the **logistic model** (or **logit model**) is used to model the probability of a certain class or event existing such as pass/fail, win/lose, alive/dead or healthy/sick. This can be extended to model several classes of events such as determining whether an image contains a cat, dog, lion, etc. Each object being detected in the image would be assigned a probability between 0 and 1, with a sum of one.
#
# Logistic regression is a statistical model that in its basic form uses a logistic function to model a binary dependent variable, although many more complex extensions exist. Logistic model has a dependent variable with two possible values, such as healthy/sick which is represented by an indicator variable, where the two values are labeled "0" and "1". The corresponding probability of the value labeled "1" can vary between 0 (certainly the value "0") and 1 (certainly the value "1"), hence the labeling.
#
# An explanation of logistic regression can begin with an explanation of the standard **logistic function**. The logistic function is a **sigmoid function**, which takes any real input $z$, and outputs a value between zero and one. As shown in following figure, the logistic function (or sigmoid function)  $\sigma (z)$ output a value between 0 and 1.
#
# $$\sigma (z)={\frac {1}{1+e^{-z}}}$$
#
# ![Logistic function.](https://upload.wikimedia.org/wikipedia/commons/8/88/Logistic-curve.svg)
#
# Let us assume that $z$ is a linear regression of $d$ features $\mathbf{x}=[x_1, x_2, ..., x_d]$,
# we express $z$ as
# \begin{align*}
# z & = w_1  x_1 + ... + w_d  x_d + b\\
#  & =\mathbf{w}^\top \mathbf{x} + b
# \end{align*}
# Then we can model the probability of the dependent variable $y$ equaling 1 as
# \begin{align*}
#  p(y=1| \mathbf{x})=\sigma (z) & =\frac {1}{1+e^{-(w_1  x_1 + ... + w_d  x_d + b)}}\\
#  &=\frac {1}{1+e^{-(\mathbf{w}^\top \mathbf{x} + b)}}.
#  \end{align*}
#
#  ### Model parameters
#  In logistic regression model,
#  \begin{align*}
#  & z  = w_1  x_1 + ... + w_d  x_d + b\\
#  & p(y=1| \mathbf{x}) =\sigma (z)  =\frac {1}{1+e^{-(w_1  x_1 + ... + w_d  x_d + b)}}.
#  \end{align*}
#  $[\mathbf{w}, b]=[w_1, w_2, ..., w_d, b]$ are known as model **paremeters**. We need to estimate the optimal values of those **paremeters**.
#
#  ## 2.  Loss Function
#
# Next, we need a loss function to measure the quality of our predicted probabilities. We will rely on maximum likelihood estimation.
#
# ### Log-Likelihood
#
# The sigmoid function gives us the estimated conditional probabilities
# of each class given any input $\mathbf{x}$, e.g.,
# $\hat{y}_1$ = $P(y=\text{spam} \mid \mathbf{x})$.
# Suppose that the entire dataset $\{\mathbf{x}^{(i)}, {y}^{(i)}\}_{i=1}^n$ has $n$ examples,
# where the example indexed by $i$
# consists of a feature vector $\mathbf{x}^{(i)}$ and a one-hot label vector ${y}^{(i)}$.
# We can compare the estimates with reality
# by checking how probable the actual classes are
# according to our model, given the features:
#
# $$
# P(\mathbf{y} \mid \mathbf{X}) = \prod_{i=1}^n P({y}^{(i)} \mid \mathbf{x}^{(i)}).
# $$
#
# According to maximum likelihood estimation,
# we maximize $P(\mathbf{y} \mid \mathbf{X})$,
# which is
# equivalent to minimizing the negative log-likelihood:
#
# $$
#
# -\log P(\mathbf{y} \mid \mathbf{X}) = \sum_{i=1}^n -\log P({y}^{(i)} \mid \mathbf{x}^{(i)})
# = \sum_{i=1}^n l({y}^{(i)}, \hat{{y}}^{(i)}),
# $$
#
# where for any pair of label ${y}$ and model prediction $\hat{{y}}$ over two classes,
# the loss function $l$ is
#
# $$ l({y}, \hat{{y}}) = - \sum_{j=1}^2 y_j \log \hat{y}_j. $$
#
#
# ## 3.  Find the best parameters via Gradient Descent (**optional, you donot need to know the details in this part in this class**)
#
# ## 4. Model Prediction and Evaluation
#
# After training the logistic regression model, given any example features,
# we can predict the probability of each output class.
# Normally, we use the class with the highest predicted probability as the output class.
# The prediction is correct if it is consistent with the actual class (label).

# %% [markdown]
# # Classification (Logictic Regression) with  with scikit-learn
#
# In real practice, you do not need to implement linear regression models by yourself from scratch.
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# class sklearn.linear_model.LogisticRegression(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)

# %% [markdown]
# ![Classfication.](https://raw.githubusercontent.com/binbenliu/Teaching/main/DataMining/iris-data.png)
#
# Iris sample data, which contains information on 150 Iris flowers, 50 each from one of three Iris species: Setosa, Versicolour, and Virginica. Each flower is characterized by five attributes:
#
# - sepal length in centimeters
#
# - sepal width in centimeters
#
# - petal length in centimeters
#
# - petal width in centimeters
#
# - class (Setosa, Versicolour, Virginica)
#
#
# Here is the summary of the dataset
#
# - Number of Instances: 150 (50 in each of three classes)
#
# - Number of Attributes: 4 numeric, predictive attributes and the class
#
# - Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## 1 import the data

# %%
iris_data =  pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data',header=None)
iris_data.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# ## 2. Data statics and Visualization
# It is also possible to display the summary for all the attributes simultaneously in a table using the describe() function. If an attribute is quantitative, it will display its mean, standard deviation and various quantiles (including minimum, median, and maximum) values. If an attribute is qualitative, it will display its number of unique values and the top (most frequent) values.
#
#
# Data visualization is the display of information in a graphic or tabular format. Successful visualization requires that the data (information) be converted into a visual format so that the characteristics of the data and the relationships among data items or attributes can be analyzed or reported.

# %%
iris_data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris_data['class'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: class, dtype: int64

# %%
iris_data['sepal_width'].hist(bins=10)

# %%
iris_data['class'].replace(["Iris-setosa","Iris-versicolor", "Iris-virginica"], [0,1, 2], inplace=True)
iris_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0             5.1          3.5           1.4          0.2      0
# 1             4.9          3.0           1.4          0.2      0
# 2             4.7          3.2           1.3          0.2      0
# 3             4.6          3.1           1.5          0.2      0
# 4             5.0          3.6           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 145           6.7          3.0           5.2          2.3      2
# 146           6.3          2.5           5.0          1.9      2
# 147           6.5          3.0           5.2          2.0      2
# 148           6.2          3.4           5.4          2.3      2
# 149           5.9          3.0           5.1          1.8      2
#
# [150 rows x 5 columns]

# %% [markdown]
# ## 3 Logistic Regression - how it works

# %%
from pandas.plotting import scatter_matrix
import pandas as pd

color_wheel = {1: "#0392cf", 
               2: "#7bc043", 
               3: "#ee4035"}
colors = iris_data["class"].map(lambda x: color_wheel.get(x + 1))
ax = scatter_matrix(iris_data, color=colors, alpha=0.6, figsize=(15, 15), diagonal='hist')

# %% [markdown]
# We'll only select the first two flower classes for binary classification (~100 rows), and only use the first 2 features ('sepal_length', 'sepal_width) to demo the concept of logistic regression

# %%
iris_data.loc[ :99, ['sepal_length', 'sepal_width']].to_numpy().shape
# Out:
# (100, 2)

# %%
# Select first 2 flower classes (~100 rows)
# And first 2 features

sepal_length = iris_data.loc[ :99, ['sepal_length']].values
sepal_width = iris_data.loc[ :99, ['sepal_width']].values
labels = iris_data.loc[ :99, 'class']

print(sepal_length.size)
# Out:
# 100

# %% [markdown]
# We will also center the data. In this case, removing the mean means that
# we won't need a bias in our model and still get reasonable results. Our binary
# classification model will look like this:
#
# \begin{align*}
# z &= w_1 x_1 + w_2 x_2 + b\\
# y &= \sigma(z)
# \end{align*}
#
# If $y >= 0.5$ then we will classify the flower as a Setosa.

# %%
# you can also the data. 
#import numpy as np
#sepal_length -= np.mean(sepal_length)
#sepal_width -= np.mean(sepal_width)

# %% [markdown]
# Let's look at these two features. Note that in our case, the data set is *linearly separable*,
# meaning that it is possible to draw a line that separates the two classes.

# %%
plt.scatter(sepal_length, 
            sepal_width,
            c=labels,
            cmap=plt.cm.Paired)
plt.xlabel("sepal length")
plt.ylabel("sepal width")
# Out:
# Text(0, 0.5, 'sepal width')

# %% [markdown]
# ### Decision Boundaries
#
# We can show that $y = \sigma(z) >= 0.5$ if and only if $z >= 0$. Meaning that the
# *decision boundary* $y = 0.5$ can be expressed as $w_1 x_1 + w_2 x_2 + b = 0$. The decision
# boundary is therefore a line through the origin in the data space!
#
# The following function will help us plot a decision boundary  $w_1 x_1 + w_2 x_2 + b= 0$.
# (You're not required to know how this code works.)

# %%
def plot_sep(w1, w2, b, color='green'):
    '''
    Plot decision boundary hypothesis 
      w1 * sepal_len + w2 * sepal_wid = 0
    in input space, highlighting the hyperplane
    '''
    plt.scatter(sepal_length, 
                sepal_width,
                c=labels,
                cmap=plt.cm.Paired)
    plt.title("Separation in Input Space")
    plt.ylim([1.5,5])
    plt.xlim([4,7])
    plt.xlabel("sepal length")
    plt.ylabel("sepal width")
    # Calculate the intercept and gradient of the decision boundary.
    # Calculate the intercept and gradient of the decision boundary.
    c = -b/w2
    m = -w1/w2

    # Plot the data and the classification with the decision boundary.
    xmin, xmax = 4,7
    ymin, ymax = 1.5, 5
    xd = np.array([xmin, xmax])
    yd = m*xd + c
    plt.plot(xd, yd, 'red', lw=2, ls='--')
    plt.fill_between(xd, yd, ymin, color='tab:orange', alpha=0.2)
    plt.fill_between(xd, yd, ymax, color='tab:green', alpha=0.2)

    plt.xlim(xmin, xmax)
    plt.ylim(ymin, ymax)

    plt.show()

# %%
# Example hypothesis
#   0*sepal_len - 3*sepal_wid -10 >=0

plot_sep(0, 3, -10)

# %%
# Another example hypothesis:
#   2*sepal_len - 3*sepal_wid -7 >=0

plot_sep(2.9, -3.2, -4)

# %%
# Another example hypothesis:
#   2*sepal_len - 3*sepal_wid -7 0

plot_sep(3, -3, -7)

# %% [markdown]
# ### Using `sklearn` to find the best function

# %%
iris_data.loc[ :99, ['sepal_length', 'sepal_width']].values
# Out:
# array([[5.1, 3.5],
#        [4.9, 3. ],
#        [4.7, 3.2],
#        [4.6, 3.1],
#        [5. , 3.6],
#        [5.4, 3.9],
#        [4.6, 3.4],
#        [5. , 3.4],
#        [4.4, 2.9],
#        [4.9, 3.1],
#        [5.4, 3.7],
#        [4.8, 3.4],
#        [4.8, 3. ],
#        [4.3, 3. ],
#        [5.8, 4. ],
#        [5.7, 4.4],
#        [5.4, 3.9],
#        [5.1, 3.5],
#        [5.7, 3.8],
#        [5.1, 3.8],
#        [5.4, 3.4],
#        [5.1, 3.7],
#        [4.6, 3.6],
#        [5.1, 3.3],
#        [4.8, 3.4],
#        [5. , 3. ],
#        [5. , 3.4],
#        [5.2, 3.5],
#        [5.2, 3.4],
#        [4.7, 3.2],
#        [4.8, 3.1],
#        [5.4, 3.4],
#        [5.2, 4.1],
#        [5.5, 4.2],
#        [4.9, 3.1],
#        [5. , 3.2],
#        [5.5, 3.5],
#        [4.9, 3.1],
#        [4.4, 3. ],
#        [5.1, 3.4],
#        [5. , 3.5],
#        [4.5, 2.3],
#        [4.4, 3.2],
#        [5. , 3.5],
#        [5.1, 3.8],
#        [4.8, 3. ],
#        [5.1, 3.8],
# ...

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# class sklearn.linear_model.LogisticRegression(penalty='l2', *, dual=False, tol=0.0001, C=1.0, fit_intercept=True, intercept_scaling=1, class_weight=None, random_state=None, solver='lbfgs', max_iter=100, multi_class='auto', verbose=0, warm_start=False, n_jobs=None, l1_ratio=None)
#
# In our class, we introduced how to use Logistic Regression to classify object into two classes.
#
# At the momend, let just donciser only two class 'Iris-setosa' and 'Iris-versicolor'. Dropping all other class (Iris-virginica)

# %%
import sklearn.linear_model
model = sklearn.linear_model.LogisticRegression(fit_intercept=True)
model.fit(iris_data.loc[ :99, ['sepal_length', 'sepal_width']].values,
          iris_data.loc[ :99, 'class'].values)
# Out:
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[ 3.09621805, -3.01680617]])

# %%
model.intercept_
# Out:
# array([-7.42914365])

# %%
plot_sep( 3.09621805, -3.01680617, -7.42914365)

# %% [markdown]
# ### Calcuate probality
# Withe the best model select as
# \begin{align*}
# z &= 3.09621805 x_1 -3.01680617 x_2 -7.42914365\\
# y &= \sigma(z)
# \end{align*}
#
# First data point [5.1, 3.5]
#
# Last data point  [5.7, 2.8]

# %%
import math
import numpy as np 

def z_value(x):
  x = np.array(x)
  return np.array([3.09621805, -3.01680617]).dot(x) -7.42914365

def sigmoid(z):
  return 1 / (1 + math.exp(-z))

# %%
z1= z_value([5.1, 3.5])
y1= sigmoid(z1)
print(z1, y1)
# Out:
# -2.197253190000003 0.09999742488973194

# %%
z2= z_value([5.7, 2.8])
y2= sigmoid(z2)
print(z2, y2)
# Out:
# 1.7722419590000005 0.8547362590400512

# %% [markdown]
# ## 4. Classfication using Logistic Regression with all featuers
#
# This time we consider all the four features: sepal_length	sepal_width	petal_length	petal_width
#
# So we have our model as
# \begin{align*}
# z &= w_1 x_1 + w_2 x_2 + w_3 x_3 + w_4 x_4 + b\\
# y &= \sigma(z)
# \end{align*}
#
# or more conviently
# \begin{align*}
# z &= w_1 * sepal\_length + w_1 *	sepal\_width + w_3 *	petal\_length	+ w_4 * petal\_width + b\\
# y &= \sigma(z)
# \end{align*}

# %%
iris_data[0:50]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 0            5.1          3.5           1.4          0.2      0
# 1            4.9          3.0           1.4          0.2      0
# 2            4.7          3.2           1.3          0.2      0
# 3            4.6          3.1           1.5          0.2      0
# 4            5.0          3.6           1.4          0.2      0
# 5            5.4          3.9           1.7          0.4      0
# 6            4.6          3.4           1.4          0.3      0
# 7            5.0          3.4           1.5          0.2      0
# 8            4.4          2.9           1.4          0.2      0
# 9            4.9          3.1           1.5          0.1      0
# 10           5.4          3.7           1.5          0.2      0
# 11           4.8          3.4           1.6          0.2      0
# 12           4.8          3.0           1.4          0.1      0
# 13           4.3          3.0           1.1          0.1      0
# ...

# %%
iris_data[50:100]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 50           7.0          3.2           4.7          1.4      1
# 51           6.4          3.2           4.5          1.5      1
# 52           6.9          3.1           4.9          1.5      1
# 53           5.5          2.3           4.0          1.3      1
# 54           6.5          2.8           4.6          1.5      1
# 55           5.7          2.8           4.5          1.3      1
# 56           6.3          3.3           4.7          1.6      1
# 57           4.9          2.4           3.3          1.0      1
# 58           6.6          2.9           4.6          1.3      1
# 59           5.2          2.7           3.9          1.4      1
# 60           5.0          2.0           3.5          1.0      1
# 61           5.9          3.0           4.2          1.5      1
# 62           6.0          2.2           4.0          1.0      1
# 63           6.1          2.9           4.7          1.4      1
# ...

# %% [markdown]
# For each class, we hold-out two data points to test our model

# %%
train_index = list(range(0,48)) + list(range(50,98))
test_index = [48, 49, 98, 99]

iris_data.loc[test_index, :]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 48           5.3          3.7           1.5          0.2      0
# 49           5.0          3.3           1.4          0.2      0
# 98           5.1          2.5           3.0          1.1      1
# 99           5.7          2.8           4.1          1.3      1

# %%
import sklearn.linear_model
model = sklearn.linear_model.LogisticRegression(fit_intercept=True)
model.fit(iris_data.loc[ train_index, ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].values,
          iris_data.loc[ train_index, 'class'].values)
# Out:
# LogisticRegression()

# %%
model.coef_
# Out:
# array([[ 0.47438719, -0.83939202,  2.29247007,  0.90675399]])

# %%
model.intercept_
# Out:
# array([-7.01603624])

# %% [markdown]
# ### Test our model
# Withe the best model select as
# \begin{align*}
# z &= 0.47438719 x_1 -0.83939202 x_2 +  2.29247007 x_3 + 0.90675399 x_4 - 7.01603624\\
# y &= \sigma(z)
# \end{align*}

# %%
iris_data.loc[test_index, :]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 48           5.3          3.7           1.5          0.2      0
# 49           5.0          3.3           1.4          0.2      0
# 98           5.1          2.5           3.0          1.1      1
# 99           5.7          2.8           4.1          1.3      1

# %%
import math
import numpy as np 

def z_value_full(x):
  x = np.array(x)
  return np.array([0.47438719, -0.83939202,  2.29247007,  0.90675399]).dot(x) -7.01603624

def sigmoid(z):
  return 1 / (1 + math.exp(-z))

# %%
x1 = [	5.3,	3.7,	1.5,	0.2]
z1 = z_value_full(x1)
y1= sigmoid(z1)

x2 = [5.0,	3.3,	1.4,	0.2	]
z2 = z_value_full(x2)
y2= sigmoid(z2)

x3 = [5.1,	2.5,	3.0,	1.1]
z3 = z_value_full(x3)
y3= sigmoid(z3)

x4 = [5.7,	2.8,	4.1,	1.3]
z4 = z_value_full(x4)
y4= sigmoid(z4)

print('z1 = %f, y1 = %f' % (z1, y1))
print('z2 = %f, y2 = %f' % (z2, y2))
print('z3 = %f, y3 = %f' % (z3, y3))
print('z4 = %f, y4 = %f' % (z4, y4))
# Out:
# z1 = -3.987479, y1 = 0.018209
# z2 = -4.023285, y2 = 0.017580
# z3 = 1.179698, y3 = 0.764893
# z4 = 3.915581, y4 = 0.980460

# %%
testdata = iris_data.loc[test_index, :]
testdata
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  class
# 48           5.3          3.7           1.5          0.2      0
# 49           5.0          3.3           1.4          0.2      0
# 98           5.1          2.5           3.0          1.1      1
# 99           5.7          2.8           4.1          1.3      1

# %% [markdown]
# ### use the prediciton function in sk learn
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
testX = testdata[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].values
testY = testdata[['class']].values

# %%
model.predict(testX)
# Out:
# array([0, 0, 1, 1])

# %%
# predict_proba(X)
# The returned estimates for all classes are ordered by the label of classes.

model.predict_proba(testX)
# Out:
# array([[0.98179129, 0.01820871],
#        [0.98242048, 0.01757952],
#        [0.23510651, 0.76489349],
#        [0.01953957, 0.98046043]])

# %% [markdown]
# ## Summary
#
# * Logistic regression is a supervised machine learning classifier
#
# >> Extracts real-valued features from the input,
#
# >> Multiplies each by a weight, sums them, and
#
# >> Passes the sum through a sigmoid function to generate a probability
#
# * The weights (vector w and bias b) are learned from a labeled training set via a loss function, that must be minimized.
#
# * Minimizing this loss function
# > Iterative algorithms like gradient descent are used to find the optimal weights.
#
# * Logistic regression is also one of the most useful analytic tools,
# > be able to transparently study the importance of individual features.
#
# * Logistic regression can be used with two classes (e.g., positive and negative sentiment) or with multiple classes (multinomial logistic regression)
